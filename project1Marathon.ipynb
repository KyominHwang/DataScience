# %%
import pandas as pd
import tensorflow as tf
# Out:
# C:\Users\piter\AppData\Roaming\Python\Python37\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\piter\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\piter\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
data = pd.read_csv("marathon/marathon_2015_2017.csv")

# %%
data.head()
# Out:
#                     Name  Age M/F         City State Country   5K   10K   15K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  883  1783  2697
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  883  1783  2698
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  883  1783  2697
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  883  1784  2701
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  883  1784  2698
#
#     20K  ...   25K   30K   35K   40K  Pace  Official Time  Overall  Gender  \
# 0  3629  ...  4567  5520  6479  7359   296           7757        1       1
# 1  3628  ...  4567  5519  6479  7362   298           7788        2       2
# 2  3629  ...  4567  5520  6479  7381   299           7822        3       3
# 3  3629  ...  4567  5520  6483  7427   300           7847        4       4
# 4  3628  ...  4567  5520  6479  7407   300           7849        5       5
#
#    Division  Year
# 0         1  2015
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'M/F', 'City', 'State', 'Country', '5K', '10K', '15K',
#        '20K', 'Half', '25K', '30K', '35K', '40K', 'Pace', 'Official Time',
#        'Overall', 'Gender', 'Division', 'Year'],
#       dtype='object')

# %%
y_train = data[["5K","10K","15K","20K","Half","25K","30K","35K","40K"]]
y_train.head()
# Out:
#     5K   10K   15K   20K  Half   25K   30K   35K   40K
# 0  883  1783  2697  3629  3842  4567  5520  6479  7359
# 1  883  1783  2698  3628  3841  4567  5519  6479  7362
# 2  883  1783  2697  3629  3842  4567  5520  6479  7381
# 3  883  1784  2701  3629  3842  4567  5520  6483  7427
# 4  883  1784  2698  3628  3841  4567  5520  6479  7407

# %%
y_train.loc[0]
# Out:
# 5K       883
# 10K     1783
# 15K     2697
# 20K     3629
# Half    3842
# 25K     4567
# 30K     5520
# 35K     6479
# 40K     7359
# Name: 0, dtype: int64

# %%
x_train = np.array([5,10,15,20,21,25,30,35,40])

# %%
pd.Series.to_numpy(y_train.loc[0])
# Out:
# array([ 883, 1783, 2697, 3629, 3842, 4567, 5520, 6479, 7359], dtype=int64)

# %%
import numpy as np

# %%
user_input = int(input())
# Out:
# 1

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(1,input_dim = 1))

# %%
sgd = tf.keras.optimizers.SGD(lr = 0.001)

# %%
model.compile(loss = "mean_squared_error", optimizer = sgd)

# %%
model.fit(x_train, pd.Series.to_numpy(y_train.loc[user_input]), epochs = 5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 398.7892
# Epoch 2/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 398.7701
# Epoch 3/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 398.7466
# Epoch 4/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 398.7240
# Epoch 5/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 398.7038
# Epoch 6/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 398.6766
# Epoch 7/5000
# 1/1 [==============================] - 0s 997us/step - loss: 398.6575
# Epoch 8/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 398.6322
# Epoch 9/5000
# 1/1 [==============================] - 0s 964us/step - loss: 398.6130
# Epoch 10/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 398.5928
# Epoch 11/5000
# 1/1 [==============================] - 0s 998us/step - loss: 398.5713
# Epoch 12/5000
# ...

# %%
model.predict(np.array([40]))
# Out:
# array([[7374.3228]], dtype=float32)

# %%
print(data.loc[user_input,"40K"])
# Out:
# 7362
