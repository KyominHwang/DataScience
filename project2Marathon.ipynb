# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
data = pd.read_csv("marathon/marathon_2015_2017.csv")
data.head()
# Out:
#                     Name  Age M/F         City State Country   5K   10K   15K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  883  1783  2697
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  883  1783  2698
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  883  1783  2697
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  883  1784  2701
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  883  1784  2698
#
#     20K  ...   25K   30K   35K   40K  Pace  Official Time  Overall  Gender  \
# 0  3629  ...  4567  5520  6479  7359   296           7757        1       1
# 1  3628  ...  4567  5519  6479  7362   298           7788        2       2
# 2  3629  ...  4567  5520  6479  7381   299           7822        3       3
# 3  3629  ...  4567  5520  6483  7427   300           7847        4       4
# 4  3628  ...  4567  5520  6479  7407   300           7849        5       5
#
#    Division  Year
# 0         1  2015
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'M/F', 'City', 'State', 'Country', '5K', '10K', '15K',
#        '20K', 'Half', '25K', '30K', '35K', '40K', 'Pace', 'Official Time',
#        'Overall', 'Gender', 'Division', 'Year'],
#       dtype='object')

# %%
data = data[["M/F","Age","Pace","10K","20K","30K","Official Time"]]

# %%
data["M/F"] = data["M/F"].replace("M",1).replace("F",0)

# %%
data.head()
# Out:
#    M/F  Age  Pace   10K   20K   30K  Official Time
# 0    1   25   296  1783  3629  5520           7757
# 1    1   30   298  1783  3628  5519           7788
# 2    1   29   299  1783  3629  5520           7822
# 3    1   28   300  1784  3629  5520           7847
# 4    1   32   300  1784  3628  5520           7849

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79638 entries, 0 to 79637
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   M/F            79638 non-null  int64
#  1   Age            79638 non-null  int64
#  2   Pace           79638 non-null  int64
#  3   10K            79638 non-null  int64
#  4   20K            79638 non-null  int64
#  5   30K            79638 non-null  int64
#  6   Official Time  79638 non-null  int64
# dtypes: int64(7)
# memory usage: 4.3 MB

# %%
data_list = data.values.tolist()
data_list
# Out:
# [[1, 25, 296, 1783, 3629, 5520, 7757],
#  [1, 30, 298, 1783, 3628, 5519, 7788],
#  [1, 29, 299, 1783, 3629, 5520, 7822],
#  [1, 28, 300, 1784, 3629, 5520, 7847],
#  [1, 32, 300, 1784, 3628, 5520, 7849],
#  [1, 30, 300, 1785, 3629, 5520, 7852],
#  [1, 32, 301, 1785, 3643, 5519, 7880],
#  [1, 39, 304, 1784, 3630, 5519, 7962],
#  [1, 27, 306, 1783, 3628, 5520, 8015],
#  [1, 33, 307, 1834, 3703, 5591, 8032],
#  [1, 33, 307, 1790, 3680, 5592, 8032],
#  [1, 30, 308, 1834, 3702, 5610, 8057],
#  [1, 32, 313, 1784, 3629, 5520, 8185],
#  [1, 31, 316, 1784, 3667, 5743, 8282],
#  [1, 42, 318, 1937, 3889, 5882, 8324],
#  [1, 29, 319, 1939, 3901, 5881, 8352],
#  [1, 30, 319, 1937, 3889, 5882, 8357],
#  [1, 28, 321, 1941, 3921, 5926, 8404],
#  [1, 28, 322, 1937, 3884, 5861, 8425],
#  [1, 26, 322, 1940, 3920, 5920, 8435],
#  [1, 32, 322, 1791, 3687, 5734, 8442],
#  [1, 26, 324, 1941, 3921, 5926, 8470],
#  [1, 32, 324, 1942, 3921, 5926, 8476],
#  [1, 28, 325, 1942, 3920, 5925, 8518],
# ...

# %%
x_train = [r[0:3] for r in data_list]
y_train = [r[-1] for r in data_list]

# %%
type(x_train[0])
# Out:
# list

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(1, input_shape = (3,)))

# %%
sgd = tf.keras.optimizers.SGD(lr = 0.000001)

# %%
model.compile(loss = "mean_squared_error", optimizer = sgd)

# %%
model.fit(np.array(x_train), np.array(y_train), epochs = 20)
# Out:
# Epoch 1/20
# 2489/2489 [==============================] - 5s 2ms/step - loss: 4401.3491
# Epoch 2/20
# 2489/2489 [==============================] - 5s 2ms/step - loss: 4399.6821
# Epoch 3/20
# 2489/2489 [==============================] - 4s 2ms/step - loss: 4399.2593
# Epoch 4/20
# 2489/2489 [==============================] - 4s 2ms/step - loss: 4390.2871
# Epoch 5/20
# 2489/2489 [==============================] - 5s 2ms/step - loss: 4412.8618
# Epoch 6/20
# 2489/2489 [==============================] - 4s 2ms/step - loss: 4404.7241
# Epoch 7/20
# 2489/2489 [==============================] - 5s 2ms/step - loss: 4390.6997
# Epoch 8/20
# 2489/2489 [==============================] - 3s 1ms/step - loss: 4395.2646
# Epoch 9/20
# 2489/2489 [==============================] - 4s 2ms/step - loss: 4393.1729
# Epoch 10/20
# 2489/2489 [==============================] - 5s 2ms/step - loss: 4400.4487
# Epoch 11/20
# 2489/2489 [==============================] - 3s 1ms/step - loss: 4405.9624
# ...

# %%
model.predict([[1,25,296]])
# Out:
# array([[7728.8174]], dtype=float32)

# %%
data_list[0]
# Out:
# [1, 25, 296, 1783, 3629, 5520, 7757]

# %%
origin_data = pd.read_csv("marathon/marathon_2015_2017.csv")
origin_data.head()
# Out:
#                     Name  Age M/F         City State Country   5K   10K   15K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  883  1783  2697
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  883  1783  2698
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  883  1783  2697
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  883  1784  2701
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  883  1784  2698
#
#     20K  ...   25K   30K   35K   40K  Pace  Official Time  Overall  Gender  \
# 0  3629  ...  4567  5520  6479  7359   296           7757        1       1
# 1  3628  ...  4567  5519  6479  7362   298           7788        2       2
# 2  3629  ...  4567  5520  6479  7381   299           7822        3       3
# 3  3629  ...  4567  5520  6483  7427   300           7847        4       4
# 4  3628  ...  4567  5520  6479  7407   300           7849        5       5
#
#    Division  Year
# 0         1  2015
# ...

# %%
origin_data[(origin_data["Year"] == 2017) & (origin_data["Overall"] == 1)]
# Out:
#                   Name  Age M/F      City State Country   5K   10K   15K  \
# 53228  Kirui, Geoffrey   24   M  Keringet   NaN     KEN  925  1828  2744
#
#         20K  ...   25K   30K   35K   40K  Pace  Official Time  Overall  \
# 53228  3675  ...  4619  5581  6499  7373   297           7777        1
#
#        Gender  Division  Year
# 53228       1         1  2017
#
# [1 rows x 21 columns]

# %%
model.predict([[1,24,297]]) # ans = 7777
# Out:
# array([[7754.9185]], dtype=float32)
